# %% [markdown]
# ## Prepare
#
# **Import Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score

# %%
#reading in data
house = pd.read_csv('../datasets/train.csv', keep_default_na=False, na_values=[''])

# %%
#displaying first 5 rows
pd.set_option('display.max_columns', None)
house.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave    NA
# 1  544  531379050           60        RL          43.0     11492   Pave    NA
# 2  153  535304180           20        RL          68.0      7922   Pave    NA
# 3  318  916386060           60        RL          73.0      9802   Pave    NA
# 4  255  906425045           50        RL          82.0     14235   Pave    NA
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
#descriptive stats
house.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# ...

# %%
pd.set_option('display.max_rows', None)
house.dtypes, house.shape
# Out:
# (Id                   int64
#  PID                  int64
#  MS SubClass          int64
#  MS Zoning           object
#  Lot Frontage       float64
#  Lot Area             int64
#  Street              object
#  Alley               object
#  Lot Shape           object
#  Land Contour        object
#  Utilities           object
#  Lot Config          object
#  Land Slope          object
#  Neighborhood        object
#  Condition 1         object
#  Condition 2         object
#  Bldg Type           object
#  House Style         object
#  Overall Qual         int64
#  Overall Cond         int64
#  Year Built           int64
#  Year Remod/Add       int64
#  Roof Style          object
#  Roof Matl           object
#  Exterior 1st        object
#  Exterior 2nd        object
#  Mas Vnr Type        object
#  Mas Vnr Area       float64
#  Exter Qual          object
#  Exter Cond          object
#  Foundation          object
#  Bsmt Qual           object
#  Bsmt Cond           object
# ...

# %%
#how many null values
house.isnull().sum().sum()
# Out:
# 510

# %%
#which columns are they in?
nulls = pd.DataFrame( data = house.isnull().sum())
nulls.reset_index(inplace=True)
nulls.columns = ['vals','counts']
nulls=nulls[nulls['counts']>0]
nulls
# Out:
#               vals  counts
# 4     Lot Frontage     330
# 26    Mas Vnr Type      22
# 27    Mas Vnr Area      22
# 31       Bsmt Qual       1
# 32       Bsmt Cond       1
# 33   Bsmt Exposure       4
# 34  BsmtFin Type 1       1
# 35    BsmtFin SF 1       1
# 36  BsmtFin Type 2       2
# 37    BsmtFin SF 2       1
# 38     Bsmt Unf SF       1
# 39   Total Bsmt SF       1
# 48  Bsmt Full Bath       2
# 49  Bsmt Half Bath       2
# 60   Garage Yr Blt     114
# 61   Garage Finish       1
# 62     Garage Cars       1
# 63     Garage Area       1
# 64     Garage Qual       1
# 65     Garage Cond       1

# %%
house.shape
# Out:
# (2051, 81)

# %%
house['Lot Frontage'].replace(to_replace=np.NaN, value = '0',inplace=True)

# %%
house['Mas Vnr Area'].replace(to_replace=np.NaN,value = '0', inplace=True )

# %%
house['Mas Vnr Type'].replace(to_replace=np.NaN,value = '0', inplace=True )

# %%
house['Garage Yr Blt'].replace(to_replace=np.NaN,value = '0', inplace=True )

# %%
house.shape
# Out:
# (2051, 81)

# %%
house.dropna(inplace=True)

# %%
house.shape
# Out:
# (2044, 81)

# %%
house.isnull().sum()
# Out:
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Alley              0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# Central Air        0
# ...

# %%
# plotting 'saleprice' and 'gr liv area' to identify outliers
plt.scatter(x='Gr Liv Area' ,y='SalePrice', data=house)

# %%
#plotting on box plot as well
sns.boxplot(x='Gr Liv Area', data=house)
# Out:
# <AxesSubplot:xlabel='Gr Liv Area'>

# %%
#plotting on box plot as well
sns.boxplot(x='SalePrice', data=house)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
#dropping houses > 4000 sq ft
house[house['Gr Liv Area']>4000]
house.drop(house[house['Gr Liv Area']>4000].index, inplace = True)

# %%
house.shape
# Out:
# (2042, 81)

# %%
corr = house.corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#SalePrice correlations
plt.figure(figsize=(12,8))
sns.heatmap(house.corr()[['SalePrice']], annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation to **sales price** >.5
#
# - Overall Qual .8
# - Gr living area .72
# - Total bsmt SF .67
# - 1st Flr SF .65
# - garage cars .65
# - garage area .65
# - year built .57
# - year remod .55
# - totrms abvgrd .51

# %%
#Overall Qual correlations
plt.figure(figsize=(12,8))
sns.heatmap(house.corr()[['Overall Qual']], annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation >.5 to **overall quality**
#
# - year built .6
# - year remodeled .58
# - total bsmt sf .55
# - Gr living area .57
# - garage cars .59
# - garage area .56
#
# - 1st fl sf .48

# %% [markdown]
# I suspect collinearity between some features such as garage cars and garage area. It seems that garage cars has a higher corr to overall quality, which is strongly correlated to sales price. I think we should use Garage Cars in the model rather than area. Similar situation to 1st flr sf.

# %%
#finding correlation with SalePrice above .5
#https://medium.com/analytics-vidhya/feature-selection-techniques-2614b3b7efcd
a=(corr['SalePrice'])
df = pd.DataFrame([a[a>.5]])

df.T.sort_values(by='SalePrice', ascending = False)
# Out:
#                 SalePrice
# SalePrice        1.000000
# Overall Qual     0.804477
# Gr Liv Area      0.720935
# Total Bsmt SF    0.669201
# Garage Area      0.654984
# 1st Flr SF       0.652062
# Garage Cars      0.648238
# Year Built       0.572542
# Year Remod/Add   0.550244
# Full Bath        0.537801
# TotRms AbvGrd    0.508741

# %% [markdown]
# ## Testing correlation between features to see if they are collinear:
#  - I suspect that some of the numerical variables have relationships to one another. I want to make sure they do not throw off the model if they are related to eachother.

# %%
house[['Garage Cars','Garage Area']].corr()
# Out:
#              Garage Cars  Garage Area
# Garage Cars     1.000000     0.896787
# Garage Area     0.896787     1.000000

# %% [markdown]
# #### 'Garage area' correlation to saleprice = (.65); 'Garage Cars' correlation to saleprice = (.65); but their correlation to overall quality is garage cars (.59), garage area (.56).
#
# *I will drop Garage Area from the model.*

# %%
house[['Total Bsmt SF','1st Flr SF']].corr()
# Out:
#                Total Bsmt SF  1st Flr SF
# Total Bsmt SF       1.000000    0.812242
# 1st Flr SF          0.812242    1.000000

# %% [markdown]
# #### 'Total Bsmt SF' correlation to saleprice = (.66); '1st Flr SF' correlation to saleprice = (.65)
#
# *I will drop '1st Flr SF' from the model.*

# %%
house[['TotRms AbvGrd','Gr Liv Area']].corr()
# Out:
#                TotRms AbvGrd  Gr Liv Area
# TotRms AbvGrd       1.000000     0.811687
# Gr Liv Area         0.811687     1.000000

# %% [markdown]
# #### 'TotRms AbvGrd' correlation to saleprice = (.50); 'Gr Liv Area' correlation to saleprice = (.72)
#
# *I will drop 'TotRms AbvGrd' from the model.*

# %%
house[['Year Built','Full Bath']].corr()
# Out:
#             Year Built  Full Bath
# Year Built    1.000000   0.480725
# Full Bath     0.480725   1.000000

# %% [markdown]
# Columns To Drop from the model:
#
# - 1st Flr SF
# - Garage Area
# - TotRms AbvGrd

# %%
house.head()
# Out:
#     Id        PID  MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL            0     13517   Pave    NA
# 1  544  531379050           60        RL           43     11492   Pave    NA
# 2  153  535304180           20        RL           68      7922   Pave    NA
# 3  318  916386060           60        RL           73      9802   Pave    NA
# 4  255  906425045           50        RL           82     14235   Pave    NA
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
house.isnull().sum()
# Out:
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Alley              0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# Central Air        0
# ...

# %%
a=(corr['SalePrice'])
df = pd.DataFrame([a[a>.5]])

df.T.sort_values(by='SalePrice', ascending = False)
# Out:
#                 SalePrice
# SalePrice        1.000000
# Overall Qual     0.804477
# Gr Liv Area      0.720935
# Total Bsmt SF    0.669201
# Garage Area      0.654984
# 1st Flr SF       0.652062
# Garage Cars      0.648238
# Year Built       0.572542
# Year Remod/Add   0.550244
# Full Bath        0.537801
# TotRms AbvGrd    0.508741

# %% [markdown]
# #### Save cleaned file to the data sets folder

# %%
house_clean=house

# %%
house_clean.to_csv('../datasets/house_Clean.csv')

# %%
house.head()
# Out:
#     Id        PID  MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL            0     13517   Pave    NA
# 1  544  531379050           60        RL           43     11492   Pave    NA
# 2  153  535304180           20        RL           68      7922   Pave    NA
# 3  318  916386060           60        RL           73      9802   Pave    NA
# 4  255  906425045           50        RL           82     14235   Pave    NA
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...
