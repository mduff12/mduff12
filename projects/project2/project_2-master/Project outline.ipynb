# %% [markdown]
# ![data-science-workflow.png](attachment:e7a02173-7e5a-42f0-b938-92cb04a474f1.png)

# %% [markdown]
# # Frame
# The goal of this project is to create a regression model to predict housing prices based of the Ames Housing Data set, which includes over 70 features of data related to housing prices.

# %% [markdown]
# # Prepare
#
# **Import Data**
# - using Pandas
# - are there values that pandas should avoiding making null?
#
#         For example:
#         Pandas imports NA as null, when in reality some of the NA's mean something in the data. To override the auotmatic creation of nulls from NA,:*
#
#         < df = pd.read_csv('datasets/train.csv', keep_default_na=False, na_values=['']) >
#
#         makes sure that "NA" is NOT converted to np.NaN, and empty strings WILL be converted to np.NaN

# %% [markdown]
# **Get familiar with the data:**
#
# - what are the data types?
# - are there null values?
# - what are the values and their definitions?
# - any other questions to answer?

# %% [markdown]
# **Clean the Data:**
#
# - remove null values if needed
# - correct any apparent mistakes (negative numbers where they shouldn't be?)
# - get the data types and make sure they are correct for the data
# - drop unwanted columns
# - rename columns to make thme easier to work with, if necessary

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# - Graph the data to find patterns
#
#     - are there any correlations? use a correlation heatmap
#
#     - are there any outliers? use a box plot
#
#     - using a scatter plot, are their any visible patterns?
#
#     - use a heat map, box plot, or multiple scatter plots

# %% [markdown]
# # Analyze
#
# - **Regression Model**
#
# Make use of:
#  - train_test_split
#  - cross-validation/grid searching for hyperparameters
#  - test different features
#  - strong exploratory data analysis to question correlation and relationship across predictive variables
#  - submit to kaggle!!
#
# - **Feature engineering**
#     - variables to dummify?
#     - interaction terms?
#
# - decide on some features that will most accurately predict house prices
#
# **different model methods?**
# -  ridge & lasso
#
# 3. Predict the values for your target column in the test dataset and submit your predictions to Kaggle to see how your model does against unknown data.
#     - **Note**: Kaggle expects to see your submissions in a specific format. Check the challenge's page to make sure you are formatting your CSVs correctly!
#     - **You are limited to models you've learned in class**. In other words, you cannot use XGBoost, Neural Networks or any other advanced model for this project.
#
# 4. Evaluate your models!
#     - consider your evaluation metrics
#     - consider your baseline score
#     - how can your model be used for inference?
#     - why do you believe your model will generalize to new data?

# %% [markdown]
# # Present
# - present the results in an interpretable presentation
