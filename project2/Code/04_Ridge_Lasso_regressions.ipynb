# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
#reading in data
house = pd.read_csv('../datasets/house_Clean.csv', keep_default_na=False, na_values=[''])
pd.set_option('display.max_columns', None)

# %%
house.drop(columns = 'Unnamed: 0', inplace=True)

# %%
house.head(1)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           0.0     13517   Pave    NA
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           NA      Attchd         1976.0           RFn          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0      NA
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0    NA           NA         0        3     2010       WD      130500

# %%
house=pd.get_dummies(columns=['Bsmt Exposure','BsmtFin Type 1','Garage Type','Garage Qual'], drop_first=True, data=house)

# %% [markdown]
# #### Polynomial Features

# %%
house[['Overall Qual', 'Gr Liv Area','Total Bsmt SF',
       'Garage Cars', 'Year Built','Year Remod/Add','Full Bath',
       'Garage Type_Attchd','Garage Qual_TA',
       'Bsmt Exposure_Gd','BsmtFin Type 1_GLQ']]
# Out:
#       Overall Qual  Gr Liv Area  Total Bsmt SF  Garage Cars  Year Built  \
# 0                6         1479          725.0          2.0        1976
# 1                7         2122          913.0          2.0        1996
# 2                5         1057         1057.0          1.0        1953
# 3                5         1444          384.0          2.0        2006
# 4                6         1445          676.0          2.0        1900
# ...            ...          ...            ...          ...         ...
# 2037             8         1728         1884.0          2.0        2007
# 2038             4          861          861.0          2.0        1940
# 2039             6         1913          896.0          2.0        1928
# 2040             4         1200         1200.0          1.0        1956
# 2041             7         1804          994.0          2.0        1999
#
#       Year Remod/Add  Full Bath  Garage Type_Attchd  Garage Qual_TA  \
# 0               2005          2                   1               1
# 1               1997          2                   1               1
# 2               2007          1                   0               1
# 3               2007          2                   0               1
# 4               1993          2                   0               1
# ...              ...        ...                 ...             ...
# 2037            2007          2                   1               1
# 2038            1950          1                   0               1
# 2039            1950          1                   0               0
# 2040            1956          1                   1               1
# 2041            1999          2                   1               1
#
#       Bsmt Exposure_Gd  BsmtFin Type 1_GLQ
# 0                    0                   1
# 1                    0                   1
# 2                    0                   1
# 3                    0                   0
# 4                    0                   0
# ...                ...                 ...
# 2037                 0                   1
# 2038                 0                   0
# 2039                 0                   0
# 2040                 0                   0
# 2041                 0                   0
#
# [2042 rows x 11 columns]

# %%
#Create variables

X= house[['Overall Qual', 'Gr Liv Area','Total Bsmt SF',
       'Garage Cars', 'Year Built','Year Remod/Add','Full Bath',
       'Garage Type_Attchd','Garage Qual_TA',
       'Bsmt Exposure_Gd','BsmtFin Type 1_GLQ']]
y= house['SalePrice']

# %%
#DSIR-Lancelot/4.02-lesson-regularization
# Instantiate our PolynomialFeatures object to create all two-way terms.

poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)

# %%
# Fit and transform our X data.
X_overfit = poly.fit_transform(X)

# %%
poly.get_feature_names(X.columns)
# Out:
# ['Overall Qual',
#  'Gr Liv Area',
#  'Total Bsmt SF',
#  'Garage Cars',
#  'Year Built',
#  'Year Remod/Add',
#  'Full Bath',
#  'Garage Type_Attchd',
#  'Garage Qual_TA',
#  'Bsmt Exposure_Gd',
#  'BsmtFin Type 1_GLQ',
#  'Overall Qual^2',
#  'Overall Qual Gr Liv Area',
#  'Overall Qual Total Bsmt SF',
#  'Overall Qual Garage Cars',
#  'Overall Qual Year Built',
#  'Overall Qual Year Remod/Add',
#  'Overall Qual Full Bath',
#  'Overall Qual Garage Type_Attchd',
#  'Overall Qual Garage Qual_TA',
#  'Overall Qual Bsmt Exposure_Gd',
#  'Overall Qual BsmtFin Type 1_GLQ',
#  'Gr Liv Area^2',
#  'Gr Liv Area Total Bsmt SF',
#  'Gr Liv Area Garage Cars',
#  'Gr Liv Area Year Built',
#  'Gr Liv Area Year Remod/Add',
#  'Gr Liv Area Full Bath',
#  'Gr Liv Area Garage Type_Attchd',
#  'Gr Liv Area Garage Qual_TA',
#  'Gr Liv Area Bsmt Exposure_Gd',
#  'Gr Liv Area BsmtFin Type 1_GLQ',
#  'Total Bsmt SF^2',
#  'Total Bsmt SF Garage Cars',
#  'Total Bsmt SF Year Built',
#  'Total Bsmt SF Year Remod/Add',
#  'Total Bsmt SF Full Bath',
#  'Total Bsmt SF Garage Type_Attchd',
#  'Total Bsmt SF Garage Qual_TA',
#  'Total Bsmt SF Bsmt Exposure_Gd',
#  'Total Bsmt SF BsmtFin Type 1_GLQ',
#  'Garage Cars^2',
#  'Garage Cars Year Built',
#  'Garage Cars Year Remod/Add',
#  'Garage Cars Full Bath',
#  'Garage Cars Garage Type_Attchd',
#  'Garage Cars Garage Qual_TA',
#  'Garage Cars Bsmt Exposure_Gd',
#  'Garage Cars BsmtFin Type 1_GLQ',
#  'Year Built^2',
#  'Year Built Year Remod/Add',
#  'Year Built Full Bath',
#  'Year Built Garage Type_Attchd',
#  'Year Built Garage Qual_TA',
#  'Year Built Bsmt Exposure_Gd',
#  'Year Built BsmtFin Type 1_GLQ',
#  'Year Remod/Add^2',
#  'Year Remod/Add Full Bath',
#  'Year Remod/Add Garage Type_Attchd',
#  'Year Remod/Add Garage Qual_TA',
#  'Year Remod/Add Bsmt Exposure_Gd',
#  'Year Remod/Add BsmtFin Type 1_GLQ',
#  'Full Bath^2',
#  'Full Bath Garage Type_Attchd',
#  'Full Bath Garage Qual_TA',
#  'Full Bath Bsmt Exposure_Gd',
#  'Full Bath BsmtFin Type 1_GLQ',
#  'Garage Type_Attchd^2',
#  'Garage Type_Attchd Garage Qual_TA',
#  'Garage Type_Attchd Bsmt Exposure_Gd',
#  'Garage Type_Attchd BsmtFin Type 1_GLQ',
#  'Garage Qual_TA^2',
#  'Garage Qual_TA Bsmt Exposure_Gd',
#  'Garage Qual_TA BsmtFin Type 1_GLQ',
#  'Bsmt Exposure_Gd^2',
#  'Bsmt Exposure_Gd BsmtFin Type 1_GLQ',
#  'BsmtFin Type 1_GLQ^2']

# %%
#DSIR-Lancelot/4.02-lesson-regularization
# Create train/test splits.

X_train, X_test, y_train, y_test = train_test_split(
    X_overfit,
    y,
    test_size=0.8, # Making sure that I have much LESS for training so we'll overfit
    random_state=420
)

# %%
# Scale the data, creating a new variable
#fitting the X_train data and transforming both train and test

sc = StandardScaler()
Z_train = sc.fit_transform(X_train)
Z_test = sc.transform(X_test)

# %% [markdown]
# #### Linear Regression

# %%
lr = LinearRegression()
lr.fit(Z_train, y_train) # Fit on the SCALED data
# Out:
# LinearRegression()

# %%
# How does the model score on the training and test data?
print(f"Training R-Squared: {lr.score(Z_train, y_train)}")
print(" ")
print(f"Testing R-Squared: {lr.score(Z_test, y_test)}")
# Out:
# Training R-Squared: 0.9358518091249616
#
# Testing R-Squared: 0.8547805677318965

# %% [markdown]
# - the above r2's are telling us that the model is over fit due to high training score and low testing

# %% [markdown]
# ##### Ridge regression

# %% [markdown]
# - alpha is the strength of the regularization
# - the higher alpha, the lower the coefs (betas) - the more we are regularizing the data
# - grid searching can find the best value of alpha
# - try different values here to see what gives you the best results
# - introducing bias to reduce the variance

# %%
# Instantiate.
rr = Ridge()

# Fit on training, transformed data
rr.fit(Z_train, y_train)

# Evaluate model using R2.
print(f"Ridge Training R-Squared: {rr.score(Z_train, y_train)}")
print(f"Ridge Testing R-Squared: {rr.score(Z_test, y_test)}")
# Out:
# Ridge Training R-Squared: 0.9244799992571301
# Ridge Testing R-Squared: 0.8696872238830917

# %%
#Using grid search to find the best alpha for ridge regression
#https://machinelearningmastery.com/how-to-tune-algorithm-parameters-with-scikit-learn/rr = Ridge()

rr_alphas = np.logspace(0, 100, 100)

rr_gridsearch = GridSearchCV(estimator=rr, param_grid=dict(alpha=rr_alphas),scoring = 'r2', cv=5)

rr_gridsearch.fit(Z_train, y_train)

# summarize the results of the grid search
print(rr_gridsearch.best_score_)
print(rr_gridsearch.best_estimator_.alpha)
# Out:
# 0.8796681039044154
# 10.235310218990262

# %%
rr2 = Ridge(rr_gridsearch.best_estimator_.alpha) # Fit a single ridge model with the best alpha
rr2.fit(Z_train, y_train)
rr2.predict(X_test)
# Out:
# array([4.95430296e+10, 5.83956518e+10, 5.20223366e+10, ...,
#        6.37586361e+10, 4.97176782e+10, 6.92554366e+10])

# %%
rr2.coef_
# Out:
# array([-3126.64828677, -3176.41879895, -4388.72320275, -5253.9784105 ,
#         3535.33188983,  3000.09742537, -7078.85822927,  1100.92571828,
#         2051.73994217,  1051.97766425, -4093.6704417 ,  9481.21118279,
#        21156.27936135, 20757.21193789, 10843.61894018, -1468.22371622,
#        -1498.5616158 ,  9483.33354903,    25.1686754 , -8024.22962599,
#         8297.71196641,  9559.09770782,  3671.01156207, 11287.98691116,
#         2870.43982905,   -33.6369139 ,  -486.30609539,  9601.47074599,
#        -1030.28141728,  3109.47307774,  7705.61629128, -3190.40506798,
#        -5038.83378887, 12883.7927408 , -2123.2643545 , -2733.71378924,
#          174.10037067,  1594.59897963, -5475.41151444,  -321.84900864,
#        17495.83953942,  1773.68713825, -2918.28620963, -3723.82025636,
#          793.56013593,  1979.06608755,   865.86321151, -4967.60434429,
#        -1683.54221016,  3530.42751228,  4008.37509379, -5549.00119471,
#         1989.88573496,  1851.86694186,  1128.68662288, -3216.29948269,
#         3540.7286087 , -5288.09846411,  1560.55605239,  2551.36437257,
#         1536.26840547, -3624.88321192,  3298.88836339, -3367.64502305,
#        -1985.40618591,  5286.60334853,  2587.16536434,  1100.92571828,
#        -1640.17492726,  -178.72577256, -2784.49808223,  2051.73994217,
#        -5545.94038257, -2319.47277631,  1051.97766425, -7256.723834  ,
#        -4093.6704417 ])

# %%
rr2_coefs = list(zip(poly.get_feature_names(X.columns), rr2.coef_))

# %%
rr2_coefs_df=pd.DataFrame(data = rr2_coefs,columns=['Variable','Coef'])

# %%
pd.set_option('display.max_rows', None)
rr2_coefs_df.sort_values(by = 'Coef',ascending=False).head(10)
# Out:
#                             Variable          Coef
# 12          Overall Qual Gr Liv Area  21156.279361
# 13        Overall Qual Total Bsmt SF  20757.211938
# 40  Total Bsmt SF BsmtFin Type 1_GLQ  17495.839539
# 33         Total Bsmt SF Garage Cars  12883.792741
# 23         Gr Liv Area Total Bsmt SF  11287.986911
# 14          Overall Qual Garage Cars  10843.618940
# 27             Gr Liv Area Full Bath   9601.470746
# 21   Overall Qual BsmtFin Type 1_GLQ   9559.097708
# 17            Overall Qual Full Bath   9483.333549
# 11                    Overall Qual^2   9481.211183

# %% [markdown]
# #### LASSO regression

# %%
#DSIR-Lancelot/4.02-lesson-regularization
# Instantiate.
l1 = Lasso()

# Fit on training, transformed data
l1.fit(Z_train, y_train)

# Evaluate model using R2.
print(f"LASSO Training R-Squared: {l1.score(Z_train, y_train)}")
print(f"LASSO Testing R-Squared: {l1.score(Z_test, y_test)}")
# Out:
# LASSO Training R-Squared: 0.9263567054783934
# LASSO Testing R-Squared: 0.8540745733440381
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103808188156.96205, tolerance: 297140675.3249177
#   model = cd_fast.enet_coordinate_descent(

# %%
# # Set up a list of Lasso alphas to check.
lasso_cv = LassoCV()

l_alphas = np.logspace(-3, 5, 20)

# # Cross-validate over our list of Lasso alphas.
lasso_cv = LassoCV(alphas=l_alphas, cv=5)

# # Fit model using best ridge alpha!
lasso_cv.fit(Z_train, y_train);
# Out:
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4229853200.6072693, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14258962742.564545, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21669586450.88301, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53401052636.56668, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67452484172.703445, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74211273173.27763, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76676634662.556, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77416005261.28918, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77490383706.78253, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77321174367.34685, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77071985978.65446, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76804785673.38873, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76542049010.50975, tolerance: 241509551.1669583
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 512748988.6638794, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1790470850.704132, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 957543298.3181152, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19563474125.07527, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56754180156.81998, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74697348170.51176, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81164485142.43964, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83568048618.56389, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84266322133.48898, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84305776540.78769, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84104539821.65013, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83823878195.4403, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83524713671.5878, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83229374654.61542, tolerance: 238725567.95101592
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 625991696.4856567, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2659147605.195801, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4159315795.5729065, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36383858581.975845, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62949757853.73959, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72055631411.6925, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74979711764.36444, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75832126272.99826, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75942693232.35097, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75793482381.17346, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75563386705.85156, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75318357608.16585, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75081718251.49547, tolerance: 240622544.34334356
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 743629134.8815308, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2619211425.8194275, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6274176035.2716675, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50082456805.18327, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67379286815.30937, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73965139207.39815, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76303966701.01926, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77005150410.57642, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77038111042.16776, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76824299285.1711, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76531122839.38708, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76221907991.73122, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75919363211.36708, tolerance: 217097162.40434742
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2552435155.709839, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4059069967.1130676, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5538823537.961029, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50845766178.4931, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 68829929502.08064, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75757770074.00845, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78452215571.34006, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79335531521.5044, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79504195355.81291, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79405134743.41144, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79214395228.22873, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78999035771.99902, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78783659661.80824, tolerance: 250312274.48286057
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/merylduff/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29337408056.506454, tolerance: 297140675.3249177
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_cv.alpha_
# Out:
# 112.88378916846884

# %%
# Evaluate model using R2.
print(f"LASSO Training R-Squared: {lasso_cv.score(Z_train, y_train)}")
print(f"LASSO Testing R-Squared: {lasso_cv.score(Z_test, y_test)}")
# Out:
# LASSO Training R-Squared: 0.9189885743939658
# LASSO Testing R-Squared: 0.8797043331960875

# %%
lasso_cv.coef_
# Out:
# array([-10822.43629849, -13207.4518367 ,  -2738.21762831,  -2214.41472181,
#          9184.48933399,   8534.09231841,   -548.43980374,   4350.31385116,
#         15801.84826888,      0.        ,     -0.        ,     -0.        ,
#         57900.99423904,  43273.57656056,      0.        ,     -0.        ,
#            -0.        ,   2135.2923259 ,     -0.        , -14471.40126231,
#         17559.45584801,  13213.6740828 ,   -626.32581026,  13168.73659662,
#            -0.        ,     -0.        ,  -2435.05208784,   3783.62124065,
#            -0.        ,      0.        ,   4144.24293962,  -9524.83865519,
#        -18504.00319519,  22500.77167377,  -2158.44756735,  -7938.46064258,
#            -0.        ,      0.        , -13078.65999584,     -0.        ,
#         20555.20822729,      0.        ,     -0.        ,  -5209.37598288,
#            -0.        ,   1869.51268198,   2166.61035838,  -9356.47605711,
#            -0.        ,      0.        ,      0.        , -12416.30279438,
#           790.6714733 ,      0.        ,      0.        ,   -955.53680202,
#             0.        ,     -0.        ,      0.        ,    142.37566596,
#             0.        ,  -2533.81353468,   6171.35128366,  -2945.84341034,
#             0.        ,   4814.26928244,   3147.97456248,      0.        ,
#             0.        ,      0.        ,  -4850.08832049,      0.        ,
#         -2886.6684894 ,     -0.        ,      0.        ,  -7324.2119222 ,
#        -14173.34832848])

# %%
list(zip(poly.get_feature_names(X.columns), lasso_cv.coef_))
# Out:
# [('Overall Qual', -10822.43629848916),
#  ('Gr Liv Area', -13207.451836698992),
#  ('Total Bsmt SF', -2738.217628310317),
#  ('Garage Cars', -2214.414721809061),
#  ('Year Built', 9184.489333991702),
#  ('Year Remod/Add', 8534.092318413506),
#  ('Full Bath', -548.4398037365063),
#  ('Garage Type_Attchd', 4350.313851164071),
#  ('Garage Qual_TA', 15801.84826887637),
#  ('Bsmt Exposure_Gd', 0.0),
#  ('BsmtFin Type 1_GLQ', -0.0),
#  ('Overall Qual^2', -0.0),
#  ('Overall Qual Gr Liv Area', 57900.99423904039),
#  ('Overall Qual Total Bsmt SF', 43273.576560557885),
#  ('Overall Qual Garage Cars', 0.0),
#  ('Overall Qual Year Built', -0.0),
#  ('Overall Qual Year Remod/Add', -0.0),
#  ('Overall Qual Full Bath', 2135.2923259027275),
#  ('Overall Qual Garage Type_Attchd', -0.0),
#  ('Overall Qual Garage Qual_TA', -14471.401262314663),
#  ('Overall Qual Bsmt Exposure_Gd', 17559.455848009704),
#  ('Overall Qual BsmtFin Type 1_GLQ', 13213.674082804582),
#  ('Gr Liv Area^2', -626.3258102573395),
#  ('Gr Liv Area Total Bsmt SF', 13168.736596615317),
#  ('Gr Liv Area Garage Cars', -0.0),
#  ('Gr Liv Area Year Built', -0.0),
#  ('Gr Liv Area Year Remod/Add', -2435.0520878449706),
#  ('Gr Liv Area Full Bath', 3783.621240654956),
#  ('Gr Liv Area Garage Type_Attchd', -0.0),
#  ('Gr Liv Area Garage Qual_TA', 0.0),
#  ('Gr Liv Area Bsmt Exposure_Gd', 4144.242939622147),
#  ('Gr Liv Area BsmtFin Type 1_GLQ', -9524.838655188065),
#  ('Total Bsmt SF^2', -18504.003195187277),
#  ('Total Bsmt SF Garage Cars', 22500.771673771396),
#  ('Total Bsmt SF Year Built', -2158.447567349435),
#  ('Total Bsmt SF Year Remod/Add', -7938.460642577353),
#  ('Total Bsmt SF Full Bath', -0.0),
#  ('Total Bsmt SF Garage Type_Attchd', 0.0),
#  ('Total Bsmt SF Garage Qual_TA', -13078.65999584183),
#  ('Total Bsmt SF Bsmt Exposure_Gd', -0.0),
#  ('Total Bsmt SF BsmtFin Type 1_GLQ', 20555.20822728533),
#  ('Garage Cars^2', 0.0),
#  ('Garage Cars Year Built', -0.0),
#  ('Garage Cars Year Remod/Add', -5209.375982877287),
#  ('Garage Cars Full Bath', -0.0),
#  ('Garage Cars Garage Type_Attchd', 1869.5126819780446),
#  ('Garage Cars Garage Qual_TA', 2166.61035838478),
#  ('Garage Cars Bsmt Exposure_Gd', -9356.476057112397),
#  ('Garage Cars BsmtFin Type 1_GLQ', -0.0),
#  ('Year Built^2', 0.0),
#  ('Year Built Year Remod/Add', 0.0),
#  ('Year Built Full Bath', -12416.302794384826),
#  ('Year Built Garage Type_Attchd', 790.6714733001037),
#  ('Year Built Garage Qual_TA', 0.0),
#  ('Year Built Bsmt Exposure_Gd', 0.0),
#  ('Year Built BsmtFin Type 1_GLQ', -955.53680202238),
#  ('Year Remod/Add^2', 0.0),
#  ('Year Remod/Add Full Bath', -0.0),
#  ('Year Remod/Add Garage Type_Attchd', 0.0),
#  ('Year Remod/Add Garage Qual_TA', 142.37566596237173),
#  ('Year Remod/Add Bsmt Exposure_Gd', 0.0),
#  ('Year Remod/Add BsmtFin Type 1_GLQ', -2533.813534678524),
#  ('Full Bath^2', 6171.351283659717),
#  ('Full Bath Garage Type_Attchd', -2945.843410343457),
#  ('Full Bath Garage Qual_TA', 0.0),
#  ('Full Bath Bsmt Exposure_Gd', 4814.269282440856),
#  ('Full Bath BsmtFin Type 1_GLQ', 3147.9745624835623),
#  ('Garage Type_Attchd^2', 0.0),
#  ('Garage Type_Attchd Garage Qual_TA', 0.0),
#  ('Garage Type_Attchd Bsmt Exposure_Gd', 0.0),
#  ('Garage Type_Attchd BsmtFin Type 1_GLQ', -4850.088320485744),
#  ('Garage Qual_TA^2', 0.0),
#  ('Garage Qual_TA Bsmt Exposure_Gd', -2886.6684894045084),
#  ('Garage Qual_TA BsmtFin Type 1_GLQ', -0.0),
#  ('Bsmt Exposure_Gd^2', 0.0),
#  ('Bsmt Exposure_Gd BsmtFin Type 1_GLQ', -7324.2119222048),
#  ('BsmtFin Type 1_GLQ^2', -14173.348328484948)]

# %%
lasso_df = pd.DataFrame(lasso_cv.coef_, columns=['Coefficient'], 
                        index=poly.get_feature_names(X.columns))
lasso_df.sort_values(by="Coefficient", ascending=False)
# Out:
#                                         Coefficient
# Overall Qual Gr Liv Area               57900.994239
# Overall Qual Total Bsmt SF             43273.576561
# Total Bsmt SF Garage Cars              22500.771674
# Total Bsmt SF BsmtFin Type 1_GLQ       20555.208227
# Overall Qual Bsmt Exposure_Gd          17559.455848
# Garage Qual_TA                         15801.848269
# Overall Qual BsmtFin Type 1_GLQ        13213.674083
# Gr Liv Area Total Bsmt SF              13168.736597
# Year Built                              9184.489334
# Year Remod/Add                          8534.092318
# Full Bath^2                             6171.351284
# Full Bath Bsmt Exposure_Gd              4814.269282
# Garage Type_Attchd                      4350.313851
# Gr Liv Area Bsmt Exposure_Gd            4144.242940
# Gr Liv Area Full Bath                   3783.621241
# Full Bath BsmtFin Type 1_GLQ            3147.974562
# Garage Cars Garage Qual_TA              2166.610358
# Overall Qual Full Bath                  2135.292326
# Garage Cars Garage Type_Attchd          1869.512682
# Year Built Garage Type_Attchd            790.671473
# Year Remod/Add Garage Qual_TA            142.375666
# Garage Cars BsmtFin Type 1_GLQ            -0.000000
# Garage Cars Year Built                    -0.000000
# Garage Cars Full Bath                     -0.000000
# Year Built^2                               0.000000
# Year Built Year Remod/Add                  0.000000
# Garage Cars^2                              0.000000
# Total Bsmt SF Full Bath                   -0.000000
# Year Built Garage Qual_TA                  0.000000
# Year Built Bsmt Exposure_Gd                0.000000
# Year Remod/Add^2                           0.000000
# Total Bsmt SF Bsmt Exposure_Gd            -0.000000
# Year Remod/Add Garage Type_Attchd          0.000000
# Year Remod/Add Bsmt Exposure_Gd            0.000000
# Full Bath Garage Qual_TA                   0.000000
# Garage Type_Attchd^2                       0.000000
# Garage Type_Attchd Garage Qual_TA          0.000000
# Garage Type_Attchd Bsmt Exposure_Gd        0.000000
# Year Remod/Add Full Bath                  -0.000000
# Garage Qual_TA^2                           0.000000
# Garage Qual_TA BsmtFin Type 1_GLQ         -0.000000
# Total Bsmt SF Garage Type_Attchd           0.000000
# Bsmt Exposure_Gd                           0.000000
# BsmtFin Type 1_GLQ                        -0.000000
# Overall Qual^2                            -0.000000
# Bsmt Exposure_Gd^2                         0.000000
# Overall Qual Garage Cars                   0.000000
# Overall Qual Year Built                   -0.000000
# Gr Liv Area Garage Qual_TA                 0.000000
# Gr Liv Area Garage Type_Attchd            -0.000000
# Overall Qual Year Remod/Add               -0.000000
# Overall Qual Garage Type_Attchd           -0.000000
# Gr Liv Area Year Built                    -0.000000
# Gr Liv Area Garage Cars                   -0.000000
# Full Bath                               -548.439804
# Gr Liv Area^2                           -626.325810
# Year Built BsmtFin Type 1_GLQ           -955.536802
# Total Bsmt SF Year Built               -2158.447567
# Garage Cars                            -2214.414722
# Gr Liv Area Year Remod/Add             -2435.052088
# Year Remod/Add BsmtFin Type 1_GLQ      -2533.813535
# Total Bsmt SF                          -2738.217628
# Garage Qual_TA Bsmt Exposure_Gd        -2886.668489
# Full Bath Garage Type_Attchd           -2945.843410
# Garage Type_Attchd BsmtFin Type 1_GLQ  -4850.088320
# Garage Cars Year Remod/Add             -5209.375983
# Bsmt Exposure_Gd BsmtFin Type 1_GLQ    -7324.211922
# Total Bsmt SF Year Remod/Add           -7938.460643
# Garage Cars Bsmt Exposure_Gd           -9356.476057
# Gr Liv Area BsmtFin Type 1_GLQ         -9524.838655
# Overall Qual                          -10822.436298
# Year Built Full Bath                  -12416.302794
# Total Bsmt SF Garage Qual_TA          -13078.659996
# Gr Liv Area                           -13207.451837
# BsmtFin Type 1_GLQ^2                  -14173.348328
# Overall Qual Garage Qual_TA           -14471.401262
# Total Bsmt SF^2                       -18504.003195

# %% [markdown]
# ### Kaggle Submission

# %%
kaggle = pd.read_csv('./datasets/test.csv', keep_default_na=False, na_values=[''])

# %% [markdown]
# #### Feature engineering on Kaggle Data

# %%
# Dummifying:
kaggle=pd.get_dummies(columns=['Bsmt Exposure','BsmtFin Type 1','Garage Type','Garage Qual'], drop_first=True, data=kaggle)

# %%
Kfeatures = kaggle[['Overall Qual', 'Gr Liv Area','Total Bsmt SF',
       'Garage Cars', 'Year Built','Year Remod/Add','Full Bath',
       'Garage Type_Attchd','Garage Qual_TA',
       'Bsmt Exposure_Gd','BsmtFin Type 1_GLQ']]

# %%
Kfeatures.isnull().sum()
# Out:
# Overall Qual          0
# Gr Liv Area           0
# Total Bsmt SF         0
# Garage Cars           0
# Year Built            0
# Year Remod/Add        0
# Full Bath             0
# Garage Type_Attchd    0
# Garage Qual_TA        0
# Bsmt Exposure_Gd      0
# BsmtFin Type 1_GLQ    0
# dtype: int64

# %%
#Polynomial transformation

# %%
X= Kfeatures

# %%
#instantiate & fit_transform polynomial features
pf = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_pf = pf.fit_transform(X)

# %%
#Scaling the Data
sc = StandardScaler()
Z = sc.fit_transform(X_pf)

# %%
#Predict using Ridge Regression model
kaggle_preds6 = rr.predict(Z)

# %%
#Predict using Lasso Regression model
kaggle_preds7 = l.predict(Z)

# %%
kaggle_preds9 = lasso_cv.predict(Z)

# %% [markdown]
# #### Make a new Data frame

# %%
preds_dict = {
    'Id': kaggle['Id'],
    'SalePrice': kaggle_preds9
}

# %%
kaggle_preds9_tocsv = pd.DataFrame(preds_dict)

# %%
kaggle_preds9_tocsv.to_csv('Kaggle_preds9.csv',index=False,)
